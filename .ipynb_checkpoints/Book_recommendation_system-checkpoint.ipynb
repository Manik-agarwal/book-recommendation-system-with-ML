# %% [markdown]
# # The Data

# %% [markdown]
# **The Book-Crossing dataset comprises 3 files.**
# * Users :
# Contains the users. Note that user IDs (User-ID) have been anonymized and map to integers. Demographic data is provided (Location, Age) if available. Otherwise, these fields contain NULL values.
# * Books :
# Books are identified by their respective ISBN. Invalid ISBNs have already been removed from the dataset. Moreover, some content-based information is given (Book-Title, Book-Author, Year-Of-Publication, Publisher), obtained from Amazon Web Services. Note that in the case of several authors, only the first is provided. URLs linking to cover images are also given, appearing in three different flavors (Image-URL-S, Image-URL-M, Image-URL-L), i.e., small, medium, large. These URLs point to the Amazon website.
# * Ratings :
# Contains the book rating information. Ratings (Book-Rating) are either explicit, expressed on a scale from 1-10 (higher values denoting higher appreciation), or implicit, expressed by 0.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
import os

# %%
books=pd.read_csv("Books.csv")
users=pd.read_csv("Users.csv")
ratings=pd.read_csv("ratings.csv")
# Out:
# C:\Users\91750\AppData\Local\Temp\ipykernel_25812\489738674.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("Books.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %% [markdown]
# **CHECKING FOR NULL VALUES**

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # DATA PREPROCESSING

# %%
ratings_with_name=ratings.merge(books,on='ISBN')

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
num_ratings_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_ratings_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)

# %%
num_ratings_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df=ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg-rating'},inplace=True)

# %%
avg_rating_df
# Out:
#                                                Book-Title  avg-rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df=num_ratings_df.merge(avg_rating_df,on='Book-Title')

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg-rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
popular_df=popular_df[popular_df['num_ratings']>=250].sort_values('avg-rating',ascending=False).head(50)

# %%
popular_df.sample(5)
# Out:
#                                                Book-Title  num_ratings  \
# 74750                           Girl with a Pearl Earring          526
# 183573                                  The Da Vinci Code          898
# 168719  Stupid White Men ...and Other Sorry Excuses fo...          283
# 233370  Where the Heart Is (Oprah's Book Club (Paperba...          585
# 191589               The Hitchhiker's Guide to the Galaxy          268
#
#         avg-rating
# 74750     4.218631
# 183573    4.642539
# 168719    4.356890
# 233370    4.105983
# 191589    4.328358

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-L','num_ratings','avg-rating']]
popular_df.head(10)
# Out:
#                                            Book-Title     Book-Author  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)   J. K. Rowling
# 3        Harry Potter and the Goblet of Fire (Book 4)   J. K. Rowling
# 5      Harry Potter and the Sorcerer's Stone (Book 1)   J. K. Rowling
# 9   Harry Potter and the Order of the Phoenix (Boo...   J. K. Rowling
# 13   Harry Potter and the Chamber of Secrets (Book 2)   J. K. Rowling
# 16  The Hobbit : The Enchanting Prelude to The Lor...  J.R.R. TOLKIEN
# 17  The Fellowship of the Ring (The Lord of the Ri...  J.R.R. TOLKIEN
# 26  Harry Potter and the Sorcerer's Stone (Harry P...   J. K. Rowling
# 28     The Two Towers (The Lord of the Rings, Part 2)  J.R.R. TOLKIEN
# 39                              To Kill a Mockingbird      Harper Lee
#
#                                           Image-URL-L  num_ratings  avg-rating
# 0   http://images.amazon.com/images/P/0439136350.0...          428    5.852804
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA) of Book Ratings
# ## Introduction
# **In this analysis, we aim to explore a dataset of books to understand the distribution of book ratings and identify the most popular books and authors. The dataset contains information about book titles, authors, and their average ratings.**

# %%
top_rated=popular_df.sort_values('avg-rating',ascending=False)

top_rated=top_rated[:20]

plt.figure(figsize=(15,8))

sns.barplot(data=top_rated,y='Book-Title',x='avg-rating')

plt.ylabel('Title',fontsize=15)

plt.xlabel('Average Ratings',fontsize=15) 

plt.title("TOP 20 RATED BOOKS",fontsize=20)

plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
ratings['Book-Rating'].hist(bins=5)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')
plt.show()

# %%
author_ratings = popular_df.groupby('Book-Author')['avg-rating'].mean().reset_index()

# Find top 5 authors based on average ratings
top_authors = author_ratings.sort_values('avg-rating', ascending=False).head(5)

# Filter books by these top 5 authors
top_authors_list = top_authors['Book-Author'].tolist()
top_authors_books = popular_df[popular_df['Book-Author'].isin(top_authors_list)]

# Plot the top 5 authors
plt.figure(figsize=(15,8))
sns.barplot(data=top_authors, y='Book-Author', x='avg-rating')

plt.xlabel('Average Ratings', fontsize=15)
plt.ylabel('Author', fontsize=15)
plt.title("TOP 5 RATED AUTHORS", fontsize=20)

plt.show()

# %% [markdown]
# # Collaborative Filtering: User-Based Recommender System
# * **Introduction**
#  **Collaborative filtering is a popular technique used in recommendation systems to predict user preferences based on past interactions and the behavior of similar users. The user-based collaborative filtering approach specifically focuses on finding users with similar preferences and recommending items that those similar users have liked.**
#
# ## Overview of User-Based Collaborative Filtering
# * **User-based collaborative filtering works on the principle that if users have similar preferences in the past, they are likely to have similar preferences in the future. This method uses the similarity between users to generate recommendations.**
#
# ### Key Concepts
# * **User Similarity: Measures how similar two users are based on their ratings or interactions.
# Neighborhood: A group of users who are most similar to the target user.
# Recommendation Generation: Recommends items to the target user based on the preferences of the neighborhood.**

# %%
x=ratings_with_name.groupby('User-ID').count()['Book-Rating']>=200
req_users=x[x].index
req_users
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=816)

# %%
filtered_rating=ratings_with_name[ratings_with_name['User-ID'].isin(req_users)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index

# %%
final_ratings=filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
pt=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

cs=cosine_similarity(pt)

# %%
cs.shape
# Out:
# (707, 707)

# %% [markdown]
# # RECOMMENDTION FUNCTION

# %%
def recommend(book_name):
    index=np.where(pt.index==book_name)[0][0]
    similar_items=sorted(list(enumerate(cs[index])),key=lambda x:x[1],reverse=True)[1:5]

    data=[]
    for i in similar_items:
        item=[]
        temp_df=books[books['Book-Title']==pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)

    return data

# %%
recommend('Animal Farm')
# Out:
# [['1984',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451524934.01.MZZZZZZZ.jpg'],
#  ['Angus, Thongs and Full-Frontal Snogging: Confessions of Georgia Nicolson',
#   'Louise Rennison',
#   'http://images.amazon.com/images/P/0064472272.01.MZZZZZZZ.jpg'],
#  ['Midnight',
#   'Dean R. Koontz',
#   'http://images.amazon.com/images/P/0425118703.01.MZZZZZZZ.jpg'],
#  ['Second Nature',
#   'Alice Hoffman',
#   'http://images.amazon.com/images/P/0399139087.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %% [markdown]
# ### MODEL DOWNLOADING

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(cs,open('similarity_scores.pkl','wb'))
